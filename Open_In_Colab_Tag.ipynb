# %% [markdown]
# # Add "Open in Colab" Tag

# %%
import os
import nbformat

# Directory containing your Jupyter notebooks
directory = '.'

# Function to add a cell to the beginning of a notebook
def add_cell_to_notebook(notebook_path, cell_content):
    with open(notebook_path, 'r', encoding='utf-8') as f:
        nb = nbformat.read(f, as_version=4)

    # Check if the first cell already contains the "Open In Colab" badge and remove it if it does
    if nb.cells and 'Open In Colab' in nb.cells[0].source:
        nb.cells.pop(0)
        print(f'{relative_path}: Removed cell.')
    
    # Create a new cell with the specified content
    new_cell = nbformat.v4.new_markdown_cell(cell_content)
    
    # Add the new cell to the beginning of the notebook
    nb.cells.insert(0, new_cell)

    # Remove 'id' property from all cells
    for cell in nb.cells: 
        if 'id' in cell:
            id = cell['id']
            del cell['id']  
            print(f'Removed {id} from {notebook_path}.') 
    
    with open(notebook_path, 'w', encoding='utf-8') as f:
        nbformat.write(nb, f)
    print(f'{notebook_path}: Added cell.')


# Loop through all files in the directory
for root, dirs, files in os.walk(directory):
    for filename in files:
        if filename.endswith('.ipynb'):
            notebook_path = os.path.join(root, filename)
            relative_path = os.path.relpath(notebook_path, directory)
            colab_link = f'https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/{relative_path}'
            badge = f'<a target="_blank" href="{colab_link}">\n  <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>\n</a>'
            cell_content = f'{badge}'
            add_cell_to_notebook(notebook_path, cell_content)

print("FINISHED: Added cells to all notebooks.")
# Out:
# Open_In_Colab_Tag.ipynb: Removed cell.
# Removed f86bf485 from ./Open_In_Colab_Tag.ipynb.
# ./Open_In_Colab_Tag.ipynb: Added cell.
# 1_Basics/20_Library.ipynb: Removed cell.
# Removed 51fa83d2 from ./1_Basics/20_Library.ipynb.
# ./1_Basics/20_Library.ipynb: Added cell.
# 1_Basics/08_Lists.ipynb: Removed cell.
# Removed 76069f70 from ./1_Basics/08_Lists.ipynb.
# ./1_Basics/08_Lists.ipynb: Added cell.
# 1_Basics/09_Dictionaries.ipynb: Removed cell.
# Removed 15dccf4f from ./1_Basics/09_Dictionaries.ipynb.
# ./1_Basics/09_Dictionaries.ipynb: Added cell.
# 1_Basics/02_Variables.ipynb: Removed cell.
# Removed 8e174215 from ./1_Basics/02_Variables.ipynb.
# ./1_Basics/02_Variables.ipynb: Added cell.
# 1_Basics/29_Matplotlib_Plotting.ipynb: Removed cell.
# Removed 0739a3d8 from ./1_Basics/29_Matplotlib_Plotting.ipynb.
# ./1_Basics/29_Matplotlib_Plotting.ipynb: Added cell.
# 1_Basics/22_NumPy.ipynb: Removed cell.
# Removed c21ce89c from ./1_Basics/22_NumPy.ipynb.
# ./1_Basics/22_NumPy.ipynb: Added cell.
# 1_Basics/01_Getting_Started.ipynb: Removed cell.
# Removed 1de11238 from ./1_Basics/01_Getting_Started.ipynb.
# ./1_Basics/01_Getting_Started.ipynb: Added cell.
# 1_Basics/06_Operators_Part_1.ipynb: Removed cell.
# Removed f38460ec from ./1_Basics/06_Operators_Part_1.ipynb.
# ./1_Basics/06_Operators_Part_1.ipynb: Added cell.
# 1_Basics/07_Conditional_Statements.ipynb: Removed cell.
# Removed cc135978 from ./1_Basics/07_Conditional_Statements.ipynb.
# ./1_Basics/07_Conditional_Statements.ipynb: Added cell.
# 1_Basics/31_Matplotlib_Pandas_Plotting.ipynb: Removed cell.
# Removed e0b52868 from ./1_Basics/31_Matplotlib_Pandas_Plotting.ipynb.
# ./1_Basics/31_Matplotlib_Pandas_Plotting.ipynb: Added cell.
# 1_Basics/23_Pandas_Intro.ipynb: Removed cell.
# Removed 164ea6e5 from ./1_Basics/23_Pandas_Intro.ipynb.
# ./1_Basics/23_Pandas_Intro.ipynb: Added cell.
# 1_Basics/04_Strings.ipynb: Removed cell.
# Removed 58892545 from ./1_Basics/04_Strings.ipynb.
# ./1_Basics/04_Strings.ipynb: Added cell.
# 1_Basics/18_Modules.ipynb: Removed cell.
# Removed 778789ad from ./1_Basics/18_Modules.ipynb.
# ./1_Basics/18_Modules.ipynb: Added cell.
# 1_Basics/30_Matplotlib_Labeling.ipynb: Removed cell.
# Removed 33ec11c6 from ./1_Basics/30_Matplotlib_Labeling.ipynb.
# ./1_Basics/30_Matplotlib_Labeling.ipynb: Added cell.
# 1_Basics/11_Tuples.ipynb: Removed cell.
# Removed b60e9a37 from ./1_Basics/11_Tuples.ipynb.
# ./1_Basics/11_Tuples.ipynb: Added cell.
# 1_Basics/12_Operators_Part_2.ipynb: Removed cell.
# Removed bf999f2b from ./1_Basics/12_Operators_Part_2.ipynb.
# ./1_Basics/12_Operators_Part_2.ipynb: Added cell.
# 1_Basics/19_Exercise_Python_Library.ipynb: Removed cell.
# Removed 381f7fbf from ./1_Basics/19_Exercise_Python_Library.ipynb.
# ./1_Basics/19_Exercise_Python_Library.ipynb: Added cell.
# 1_Basics/25_Pandas_Cleaning.ipynb: Removed cell.
# Removed 26fde159 from ./1_Basics/25_Pandas_Cleaning.ipynb.
# ./1_Basics/25_Pandas_Cleaning.ipynb: Added cell.
# 1_Basics/15_Exercise_Basics.ipynb: Removed cell.
# Removed 0e9a5e69 from ./1_Basics/15_Exercise_Basics.ipynb.
# ./1_Basics/15_Exercise_Basics.ipynb: Added cell.
# 1_Basics/32_Exercise_Matplotlib_Basics.ipynb: Removed cell.
# Removed b2fefb5e from ./1_Basics/32_Exercise_Matplotlib_Basics.ipynb.
# ./1_Basics/32_Exercise_Matplotlib_Basics.ipynb: Added cell.
# 1_Basics/21_Classes.ipynb: Removed cell.
# Removed c47897d7 from ./1_Basics/21_Classes.ipynb.
# ./1_Basics/21_Classes.ipynb: Added cell.
# 1_Basics/24_Pandas_Inspection.ipynb: Removed cell.
# Removed 2121dd1d from ./1_Basics/24_Pandas_Inspection.ipynb.
# ./1_Basics/24_Pandas_Inspection.ipynb: Added cell.
# 1_Basics/27_Exercise_Pandas_Basics.ipynb: Removed cell.
# Removed f70d34a7 from ./1_Basics/27_Exercise_Pandas_Basics.ipynb.
# ./1_Basics/27_Exercise_Pandas_Basics.ipynb: Added cell.
# 1_Basics/17_Lambda.ipynb: Removed cell.
# Removed 69235b0b from ./1_Basics/17_Lambda.ipynb.
# ./1_Basics/17_Lambda.ipynb: Added cell.
# 1_Basics/16_Functions.ipynb: Removed cell.
# Removed ec9166d9 from ./1_Basics/16_Functions.ipynb.
# ./1_Basics/16_Functions.ipynb: Added cell.
# 1_Basics/28_Matplotlib_Intro.ipynb: Removed cell.
# Removed 5cb38a16 from ./1_Basics/28_Matplotlib_Intro.ipynb.
# ./1_Basics/28_Matplotlib_Intro.ipynb: Added cell.
# 1_Basics/26_Pandas_Analysis.ipynb: Removed cell.
# Removed 59804225 from ./1_Basics/26_Pandas_Analysis.ipynb.
# ./1_Basics/26_Pandas_Analysis.ipynb: Added cell.
# 1_Basics/03_Data_Types.ipynb: Removed cell.
# Removed fc6387c5 from ./1_Basics/03_Data_Types.ipynb.
# ./1_Basics/03_Data_Types.ipynb: Added cell.
# 1_Basics/13_Loops.ipynb: Removed cell.
# Removed 0babd42a from ./1_Basics/13_Loops.ipynb.
# ./1_Basics/13_Loops.ipynb: Added cell.
# 1_Basics/05_String_Formatting.ipynb: Removed cell.
# Removed 4318f7ec from ./1_Basics/05_String_Formatting.ipynb.
# ./1_Basics/05_String_Formatting.ipynb: Added cell.
# 1_Basics/10_Sets.ipynb: Removed cell.
# Removed 6434fd84 from ./1_Basics/10_Sets.ipynb.
# ./1_Basics/10_Sets.ipynb: Added cell.
# 1_Basics/14_List_Comprehensions.ipynb: Removed cell.
# Removed 07fa8c3a from ./1_Basics/14_List_Comprehensions.ipynb.
# ./1_Basics/14_List_Comprehensions.ipynb: Added cell.
# 1_Basics/Extra/Python_Terminology.ipynb: Removed cell.
# Removed 265dae1f from ./1_Basics/Extra/Python_Terminology.ipynb.
# ./1_Basics/Extra/Python_Terminology.ipynb: Added cell.
# 1_Basics/Extra/Pandas_Extract_from_Datetime.ipynb: Removed cell.
# Removed 8acd5a60 from ./1_Basics/Extra/Pandas_Extract_from_Datetime.ipynb.
# ./1_Basics/Extra/Pandas_Extract_from_Datetime.ipynb: Added cell.
# 1_Basics/Extra/Exercise_Functions_and_Modules.ipynb: Removed cell.
# Removed 74c4ce39 from ./1_Basics/Extra/Exercise_Functions_and_Modules.ipynb.
# ./1_Basics/Extra/Exercise_Functions_and_Modules.ipynb: Added cell.
# 1_Basics/Extra/Python_Style_Guide.ipynb: Removed cell.
# Removed e7176664 from ./1_Basics/Extra/Python_Style_Guide.ipynb.
# ./1_Basics/Extra/Python_Style_Guide.ipynb: Added cell.
# 2_Advanced/10_Pandas_Applying_Functions.ipynb: Removed cell.
# Removed 6422ff59 from ./2_Advanced/10_Pandas_Applying_Functions.ipynb.
# ./2_Advanced/10_Pandas_Applying_Functions.ipynb: Added cell.
# 2_Advanced/04_Pandas_Pivot_Tables.ipynb: Removed cell.
# Removed 16827b79 from ./2_Advanced/04_Pandas_Pivot_Tables.ipynb.
# ./2_Advanced/04_Pandas_Pivot_Tables.ipynb: Added cell.
# 2_Advanced/15_Matplotlib_Scatter_Plots.ipynb: Removed cell.
# Removed 83a53deb from ./2_Advanced/15_Matplotlib_Scatter_Plots.ipynb.
# ./2_Advanced/15_Matplotlib_Scatter_Plots.ipynb: Added cell.
# 2_Advanced/18_Matplotlib_Box_Plots.ipynb: Removed cell.
# Removed 79adfbb0 from ./2_Advanced/18_Matplotlib_Box_Plots.ipynb.
# ./2_Advanced/18_Matplotlib_Box_Plots.ipynb: Added cell.
# 2_Advanced/07_Pandas_Merge_DataFrames.ipynb: Removed cell.
# Removed 005cf588 from ./2_Advanced/07_Pandas_Merge_DataFrames.ipynb.
# ./2_Advanced/07_Pandas_Merge_DataFrames.ipynb: Added cell.
# 2_Advanced/13_Matplotlib_Format_Charts.ipynb: Removed cell.
# Removed 41f23a58 from ./2_Advanced/13_Matplotlib_Format_Charts.ipynb.
# ./2_Advanced/13_Matplotlib_Format_Charts.ipynb: Added cell.
# 2_Advanced/16_Matplotlib_Advanced_Customization.ipynb: Removed cell.
# Removed 3331e5fd from ./2_Advanced/16_Matplotlib_Advanced_Customization.ipynb.
# ./2_Advanced/16_Matplotlib_Advanced_Customization.ipynb: Added cell.
# 2_Advanced/02_Pandas_Data_Cleaning.ipynb: Removed cell.
# Removed 11f63dbb from ./2_Advanced/02_Pandas_Data_Cleaning.ipynb.
# ./2_Advanced/02_Pandas_Data_Cleaning.ipynb: Added cell.
# 2_Advanced/17_Matplotlib_Histograms.ipynb: Removed cell.
# Removed 951d73fb from ./2_Advanced/17_Matplotlib_Histograms.ipynb.
# ./2_Advanced/17_Matplotlib_Histograms.ipynb: Added cell.
# 2_Advanced/06_Exercise_Job_Demand.ipynb: Removed cell.
# Removed 7ee5732e from ./2_Advanced/06_Exercise_Job_Demand.ipynb.
# ./2_Advanced/06_Exercise_Job_Demand.ipynb: Added cell.
# 2_Advanced/03_Pandas_Data_Management.ipynb: Removed cell.
# Removed 33a74713 from ./2_Advanced/03_Pandas_Data_Management.ipynb.
# ./2_Advanced/03_Pandas_Data_Management.ipynb: Added cell.
# 2_Advanced/05_Pandas_Index_Management.ipynb: Removed cell.
# Removed 783e9ac8 from ./2_Advanced/05_Pandas_Index_Management.ipynb.
# ./2_Advanced/05_Pandas_Index_Management.ipynb: Added cell.
# 2_Advanced/08_Pandas_Concat_DataFrames.ipynb: Removed cell.
# Removed 4b1b45e3 from ./2_Advanced/08_Pandas_Concat_DataFrames.ipynb.
# ./2_Advanced/08_Pandas_Concat_DataFrames.ipynb: Added cell.
# 2_Advanced/20_Seaborn_Intro.ipynb: Removed cell.
# Removed ead96f99 from ./2_Advanced/20_Seaborn_Intro.ipynb.
# ./2_Advanced/20_Seaborn_Intro.ipynb: Added cell.
# 2_Advanced/19_Exercise_Skill_Pay_Analysis.ipynb: Removed cell.
# Removed 883a93f9 from ./2_Advanced/19_Exercise_Skill_Pay_Analysis.ipynb.
# ./2_Advanced/19_Exercise_Skill_Pay_Analysis.ipynb: Added cell.
# 2_Advanced/09_Pandas_Exporting_Data.ipynb: Removed cell.
# Removed 25515187 from ./2_Advanced/09_Pandas_Exporting_Data.ipynb.
# ./2_Advanced/09_Pandas_Exporting_Data.ipynb: Added cell.
# 2_Advanced/01_Pandas_Accessing_Data.ipynb: Removed cell.
# Removed 40ef77d4 from ./2_Advanced/01_Pandas_Accessing_Data.ipynb.
# ./2_Advanced/01_Pandas_Accessing_Data.ipynb: Added cell.
# 2_Advanced/11_Pandas_Explode.ipynb: Removed cell.
# Removed 1ba88f1c from ./2_Advanced/11_Pandas_Explode.ipynb.
# ./2_Advanced/11_Pandas_Explode.ipynb: Added cell.
# 2_Advanced/12_Exercise_Trending_Skills.ipynb: Removed cell.
# Removed 22d56699 from ./2_Advanced/12_Exercise_Trending_Skills.ipynb.
# ./2_Advanced/12_Exercise_Trending_Skills.ipynb: Added cell.
# 2_Advanced/14_Matplotlib_Pie_Plots.ipynb: Removed cell.
# Removed 6026e04d from ./2_Advanced/14_Matplotlib_Pie_Plots.ipynb.
# ./2_Advanced/14_Matplotlib_Pie_Plots.ipynb: Added cell.
# 3_Project/1_EDA_Intro.ipynb: Removed cell.
# Removed 1c484a6b from ./3_Project/1_EDA_Intro.ipynb.
# Removed d6a1d8be from ./3_Project/1_EDA_Intro.ipynb.
# Removed f9b894ed from ./3_Project/1_EDA_Intro.ipynb.
# Removed 58a13d06 from ./3_Project/1_EDA_Intro.ipynb.
# Removed 95a5af61 from ./3_Project/1_EDA_Intro.ipynb.
# Removed 98e801cc from ./3_Project/1_EDA_Intro.ipynb.
# Removed df7f5131 from ./3_Project/1_EDA_Intro.ipynb.
# Removed 6fd70dc8 from ./3_Project/1_EDA_Intro.ipynb.
# Removed 622c4777 from ./3_Project/1_EDA_Intro.ipynb.
# Removed 25d38805 from ./3_Project/1_EDA_Intro.ipynb.
# Removed 6a20de45 from ./3_Project/1_EDA_Intro.ipynb.
# Removed 0318e8b8 from ./3_Project/1_EDA_Intro.ipynb.
# Removed 72a9daff from ./3_Project/1_EDA_Intro.ipynb.
# Removed e380bb11 from ./3_Project/1_EDA_Intro.ipynb.
# Removed 0e68bc43 from ./3_Project/1_EDA_Intro.ipynb.
# Removed a4967f13 from ./3_Project/1_EDA_Intro.ipynb.
# Removed 1a8e0436 from ./3_Project/1_EDA_Intro.ipynb.
# Removed 4830e31f from ./3_Project/1_EDA_Intro.ipynb.
# Removed f1dd64d1 from ./3_Project/1_EDA_Intro.ipynb.
# Removed c0e52f99 from ./3_Project/1_EDA_Intro.ipynb.
# Removed ece4c2c4 from ./3_Project/1_EDA_Intro.ipynb.
# Removed 733d00ec from ./3_Project/1_EDA_Intro.ipynb.
# Removed 1ae5cf00 from ./3_Project/1_EDA_Intro.ipynb.
# Removed ebad978e from ./3_Project/1_EDA_Intro.ipynb.
# ./3_Project/1_EDA_Intro.ipynb: Added cell.
# 3_Project/4_Salary_Analysis.ipynb: Removed cell.
# Removed 90fe4238 from ./3_Project/4_Salary_Analysis.ipynb.
# ./3_Project/4_Salary_Analysis.ipynb: Added cell.
# 3_Project/5_Optimal_Skills.ipynb: Removed cell.
# Removed 223c3393 from ./3_Project/5_Optimal_Skills.ipynb.
# ./3_Project/5_Optimal_Skills.ipynb: Added cell.
# 3_Project/2_Skill_Demand.ipynb: Removed cell.
# Removed a9fcc71d from ./3_Project/2_Skill_Demand.ipynb.
# ./3_Project/2_Skill_Demand.ipynb: Added cell.
# 3_Project/3_Skills_Trend.ipynb: Removed cell.
# Removed 8dda2f75 from ./3_Project/3_Skills_Trend.ipynb.
# ./3_Project/3_Skills_Trend.ipynb: Added cell.
# FINISHED: Added cells to all notebooks.
# /Users/lukebarousse/opt/anaconda3/envs/python_course/lib/python3.11/site-packages/nbformat/__init__.py:132: MissingIDFieldWarning: Cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)

# %% [markdown]
# # Validate Files

# %%
import nbformat

# Path to your notebook
notebook_path = '1_Basics/10_Sets.ipynb'

# Load and validate the notebook
with open(notebook_path, 'r', encoding='utf-8') as f:
    nb = nbformat.read(f, as_version=4)
    try:
        nbformat.validate(nb)
        print(f"{notebook_path} is valid.")
    except nbformat.ValidationError as e:
        print(f"Validation error in {notebook_path}: {e}")
# Out:
# 1_Basics/10_Sets.ipynb is valid.

# %% [markdown]
# # Generate Chapter Titles

# %%
import os

directory = '.'
ch_dict = {}

for root, dirs, files in os.walk(directory):
    for filename in files:
        if filename.endswith('.ipynb') and '/' in root and not 'Extra' in root:
            notebook_path = os.path.join(root, filename)
            relative_path = os.path.relpath(notebook_path, directory)[:-6]
            # add to dictionary where the key is the chapter, which is the first part of the relative path
            ch = relative_path.split('/')[0]
            ch = ch.split('_')[1]
            lesson = relative_path.split('/')[1]
            # lesson = lesson.split('_')[1]
            if ch in ch_dict:
                ch_dict[ch].append(lesson)
            else:
                ch_dict[ch] = [lesson]
            # print(f'{relative_path}')

# sort the lists in each chapter
for ch in ch_dict:
    ch_dict[ch].sort()
    # for each string in the list, remove everything before the first underscore ONLY
    # for each string in the list replace underscores with spaces, but not the first underscore
    for i in range(len(ch_dict[ch])):
        ch_dict[ch][i] = '_'.join(ch_dict[ch][i].split('_')[1:])
        ch_dict[ch][i] = ch_dict[ch][i].replace('_', ' ')

for ch, lessons in ch_dict.items():
    print(f'{ch} Chapter')
    print("="*len(f'{ch} Chapter'))
    for lesson in lessons:
        print(f' - {lesson}')
    print()
# print(f'{ch_dict}')
# Out:
# Basics Chapter
# ==============
#  - Getting Started
#  - Variables
#  - Data Types
#  - Strings
#  - String Formatting
#  - Operators Part 1
#  - Conditional Statements
#  - Lists
#  - Dictionaries
#  - Sets
#  - Tuples
#  - Operators Part 2
#  - Loops
#  - List Comprehensions
#  - Exercise Basics
#  - Functions
#  - Lambda
#  - Modules
#  - Exercise Python Library
#  - Library
#  - Classes
#  - NumPy
#  - Pandas Intro
#  - Pandas Inspection
#  - Pandas Cleaning
#  - Pandas Analysis
#  - Exercise Pandas Basics
#  - Matplotlib Intro
#  - Matplotlib Plotting
#  - Matplotlib Labeling
#  - Matplotlib Pandas Plotting
#  - Exercise Matplotlib Basics
#
# Advanced Chapter
# ================
#  - Pandas Accessing Data
#  - Pandas Data Cleaning
#  - Pandas Data Management
#  - Pandas Pivot Tables
#  - Pandas Index Management
#  - Exercise Job Demand
#  - Pandas Merge DataFrames
#  - Pandas Concat DataFrames
#  - Pandas Exporting Data
#  - Pandas Applying Functions
#  - Pandas Explode
#  - Exercise Trending Skills
#  - Matplotlib Format Charts
#  - Matplotlib Pie Plots
#  - Matplotlib Scatter Plots
#  - Matplotlib Advanced Customization
#  - Matplotlib Histograms
#  - Matplotlib Box Plots
#  - Exercise Skill Pay Analysis
#  - Seaborn Intro
#
# Project Chapter
# ===============
#  - EDA Intro
#  - Skill Demand
#  - Skills Trend
#  - Salary Analysis
#  - Optimal Skills
