# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/2_Advanced/01_Pandas_Accessing_Data.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Pandas Accessing Data

# %% [markdown]
# ## Review Data
#
# Let's load in the data using `read_csv` and quickly review it using `head()`.

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.head()
# Out:
#   job_title_short                                          job_title  \
# 0   Data Engineer      DevOps Engineer - Big Data/Advanced Analytics
# 1   Data Engineer     Co-Op/Intern Software Engineer, Data Ingestion
# 2   Data Engineer                             Hybrid - Data Engineer
# 3  Data Scientist                                     Data Scientist
# 4   Data Engineer  Data Lead Engineer (with strong Python) - Remo...
#
#                              job_location        job_via job_schedule_type  \
# 0  Bari, Metropolitan City of Bari, Italy   via LinkedIn         Full-time
# 1                   Vancouver, BC, Canada   via LinkedIn         Full-time
# 2                            New York, NY   via LinkedIn         Full-time
# 3                           Hamtramck, MI      via BeBee         Full-time
# 4                                Anywhere  via Jobgether         Full-time
#
#    job_work_from_home          search_location     job_posted_date  \
# 0               False                    Italy 2023-10-24 18:16:15
# 1               False                   Canada 2023-05-05 18:37:58
# 2               False                    Sudan 2023-07-25 19:07:08
# 3               False  Illinois, United States 2023-11-30 18:05:20
# 4                True                   Panama 2023-08-13 18:32:30
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                   True                 False          Italy         NaN
# 1                  False                 False         Canada         NaN
# 2                  False                 False          Sudan        year
# 3                  False                 False  United States         NaN
# 4                  False                 False         Panama         NaN
#
#    salary_year_avg  salary_hour_avg       company_name  \
# 0              NaN              NaN    NTT DATA Italia
# 1              NaN              NaN            Kinaxis
# 2         425000.0              NaN  Durlston Partners
# 3              NaN              NaN             Apexon
# 4              NaN              NaN     FullStack Labs
#
#                                           job_skills  \
# 0  ['shell', 'python', 'bash', 'mongodb', 'mongod...
# 1  ['java', 'c#', 'mysql', 'oracle', 'docker', 'k...
# 2                                         ['python']
# 3  ['sql', 'r', 'scala', 'java', 'gcp', 'aws', 'h...
# 4  ['python', 'aws', 'tableau', 'looker', 'terraf...
#
#                                      job_type_skills
# 0  {'cloud': ['gcp', 'aws', 'azure'], 'databases'...
# 1  {'cloud': ['oracle'], 'databases': ['mysql'], ...
# 2                        {'programming': ['python']}
# 3  {'analyst_tools': ['tableau', 'sap', 'word'], ...
# 4  {'analyst_tools': ['tableau', 'looker'], 'asyn...

# %% [markdown]
# We learned how to get rows using `iloc[]` before. But we can do a lot more with it. We can actually get rows *and* columns.

# %% [markdown]
# ## iloc
#
# ### Notes
#
# * `df.iloc[]`: Select rows and columns by position.
#
# ### Examples
# Using `iloc` let's:
#
# 1. Get the first row (index 0)
# 2. Get the `job_skills` element of the 3rd (index at 2) row.
# 3. Get the `job_skills` (index 15) and `job_type_skills` (index 16) for the third (index 2) and fourth (index 3) rows.
# 4. Get the first 12 rows of the DataFrame.
# 5. Get the first five columns of the DataFrame and all of the rows.
#
# For this we'll need to know the index numbers for our DataFrame.
#
# ![image](images/iloc_visual_1.png)

# %% [markdown]
# 1. Get the first row.

# %%
df.iloc[0]
# Out:
# job_title_short                                              Data Engineer
# job_title                    DevOps Engineer - Big Data/Advanced Analytics
# job_location                        Bari, Metropolitan City of Bari, Italy
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                      Italy
# job_posted_date                                        2023-10-24 18:16:15
# job_no_degree_mention                                                 True
# job_health_insurance                                                 False
# job_country                                                          Italy
# salary_rate                                                            NaN
# salary_year_avg                                                        NaN
# salary_hour_avg                                                        NaN
# company_name                                               NTT DATA Italia
# job_skills               ['shell', 'python', 'bash', 'mongodb', 'mongod...
# job_type_skills          {'cloud': ['gcp', 'aws', 'azure'], 'databases'...
# Name: 0, dtype: object

# %% [markdown]
# 2. Get the `job_skills` element of the 3rd (index at 2) row.

# %%
df.iloc[0][15]
# Out:
# /var/folders/3d/0mw08fhx5wbc_ryrp6ywwql00000gn/T/ipykernel_56205/2485859661.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[0][15]
# "['shell', 'python', 'bash', 'mongodb', 'mongodb', 'cassandra', 'elasticsearch', 'gcp', 'aws', 'azure', 'kafka', 'hadoop', 'docker', 'kubernetes', 'terraform', 'ansible', 'git', 'jenkins']"

# %% [markdown]
# ##### Note: Use `df.iloc[0, 15]` instead of `df.iloc[0][15]` to ensure future compatibility with pandas.
#
# The use of chained indexing like df.iloc[0][15] is being deprecated in pandas, as it may lead to ambiguous behavior between positional and label-based access in future versions. By using df.iloc[0, 15], you directly specify the position of the data you want to access, which is clearer and avoids potential future errors when pandas changes how integer keys are interpreted in series indexing.
#
# So we should instead write:

# %%
df.iloc[0,15]
# Out:
# "['shell', 'python', 'bash', 'mongodb', 'mongodb', 'cassandra', 'elasticsearch', 'gcp', 'aws', 'azure', 'kafka', 'hadoop', 'docker', 'kubernetes', 'terraform', 'ansible', 'git', 'jenkins']"

# %% [markdown]
# 3. Get the `job_skills` (index 15) and `job_type_skills` (index 16) for the third (index 2) and fourth (index 3) rows.
#     * To get third (index 2) and fourth (index 3) rows: `[2,3]`
#     * To get `job_skills` and `job_type_skills` which are index 15 and index 16 retrospectively: `[15,16]`
#     * Then you put those two into a list itself to get everything between these two: `df.iloc[[2,3],[15,16]]`
#
# ![image](images/iloc_visual_2.png)
#
# **need to update this visual**

# %%
df.iloc[[2,3],[15,16]]
# Out:
#                                           job_skills  \
# 2                                         ['python']
# 3  ['sql', 'r', 'scala', 'java', 'gcp', 'aws', 'h...
#
#                                      job_type_skills
# 2                        {'programming': ['python']}
# 3  {'analyst_tools': ['tableau', 'sap', 'word'], ...

# %% [markdown]
# ##### Preview
#
# Below are a few more examples of what `iloc` can do. Pay close attention to these because we'll use them later.

# %% [markdown]
# 4. Get the first 10 rows of the DataFrame.

# %%
df.iloc[:9]
# Out:
#         job_title_short                                          job_title  \
# 0         Data Engineer      DevOps Engineer - Big Data/Advanced Analytics
# 1         Data Engineer     Co-Op/Intern Software Engineer, Data Ingestion
# 2         Data Engineer                             Hybrid - Data Engineer
# 3        Data Scientist                                     Data Scientist
# 4         Data Engineer  Data Lead Engineer (with strong Python) - Remo...
# 5  Senior Data Engineer                               Senior Data Engineer
# 6         Data Engineer                                      Data Engineer
# 7          Data Analyst      Applied Mathematician, Scientist, or Engineer
# 8  Senior Data Engineer  Sr. Big Data Engineer with Data Bricks, Loc - ...
#
#                              job_location            job_via  \
# 0  Bari, Metropolitan City of Bari, Italy       via LinkedIn
# 1                   Vancouver, BC, Canada       via LinkedIn
# 2                            New York, NY       via LinkedIn
# 3                           Hamtramck, MI          via BeBee
# 4                                Anywhere      via Jobgether
# 5                             Milford, CT       via Snagajob
# 6                                   Texas       via LinkedIn
# 7                     Copenhagen, Denmark  via BeBee Danmark
# 8                              Quincy, MA   via ZipRecruiter
#
#   job_schedule_type  job_work_from_home            search_location  \
# 0         Full-time               False                      Italy
# 1         Full-time               False                     Canada
# 2         Full-time               False                      Sudan
# 3         Full-time               False    Illinois, United States
# 4         Full-time                True                     Panama
# 5         Full-time               False  California, United States
# 6         Full-time               False       Texas, United States
# 7         Full-time               False                    Denmark
# 8         Full-time               False  California, United States
#
#       job_posted_date  job_no_degree_mention  job_health_insurance  \
# 0 2023-10-24 18:16:15                   True                 False
# 1 2023-05-05 18:37:58                  False                 False
# 2 2023-07-25 19:07:08                  False                 False
# 3 2023-11-30 18:05:20                  False                 False
# 4 2023-08-13 18:32:30                  False                 False
# 5 2023-07-28 18:06:44                  False                 False
# 6 2023-03-06 18:51:56                  False                  True
# 7 2023-07-12 18:24:10                  False                 False
# 8 2023-05-25 18:05:51                   True                 False
#
#      job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 0          Italy         NaN              NaN              NaN
# 1         Canada         NaN              NaN              NaN
# 2          Sudan        year         425000.0              NaN
# 3  United States         NaN              NaN              NaN
# 4         Panama         NaN              NaN              NaN
# 5  United States         NaN              NaN              NaN
# 6  United States        year         180000.0              NaN
# 7        Denmark         NaN              NaN              NaN
# 8  United States         NaN              NaN              NaN
#
#                         company_name  \
# 0                    NTT DATA Italia
# 1                            Kinaxis
# 2                  Durlston Partners
# 3                             Apexon
# 4                     FullStack Labs
# 5  Franchise World Headquarters, LLC
# 6                        Trepp, Inc.
# 7                          Signaloid
# 8                         Apptad Inc
#
#                                           job_skills  \
# 0  ['shell', 'python', 'bash', 'mongodb', 'mongod...
# 1  ['java', 'c#', 'mysql', 'oracle', 'docker', 'k...
# 2                                         ['python']
# 3  ['sql', 'r', 'scala', 'java', 'gcp', 'aws', 'h...
# 4  ['python', 'aws', 'tableau', 'looker', 'terraf...
# 5  ['python', 'nosql', 'sql', 'aws', 'redshift', ...
# 6  ['sql', 'python', 'java', 'scala', 'aws', 'spa...
# 7                  ['c', 'python', 'github', 'zoom']
# 8  ['sql', 'python', 'aws', 'databricks', 'spark'...
#
#                                      job_type_skills
# 0  {'cloud': ['gcp', 'aws', 'azure'], 'databases'...
# 1  {'cloud': ['oracle'], 'databases': ['mysql'], ...
# 2                        {'programming': ['python']}
# 3  {'analyst_tools': ['tableau', 'sap', 'word'], ...
# 4  {'analyst_tools': ['tableau', 'looker'], 'asyn...
# 5  {'cloud': ['aws', 'redshift'], 'other': ['flow...
# 6  {'cloud': ['aws'], 'libraries': ['spark'], 'ot...
# 7  {'other': ['github'], 'programming': ['c', 'py...
# 8  {'cloud': ['aws', 'databricks'], 'libraries': ...

# %% [markdown]
# 5. Get the first five columns of the DataFrame and all of the rows.

# %%
df.iloc[:, :5]
# Out:
#              job_title_short  \
# 0              Data Engineer
# 1              Data Engineer
# 2              Data Engineer
# 3             Data Scientist
# 4              Data Engineer
# ...                      ...
# 787681         Data Engineer
# 787682      Business Analyst
# 787683  Senior Data Engineer
# 787684      Business Analyst
# 787685      Business Analyst
#
#                                                 job_title  \
# 0           DevOps Engineer - Big Data/Advanced Analytics
# 1          Co-Op/Intern Software Engineer, Data Ingestion
# 2                                  Hybrid - Data Engineer
# 3                                          Data Scientist
# 4       Data Lead Engineer (with strong Python) - Remo...
# ...                                                   ...
# 787681                              Data Engineer (f/m/d)
# 787682                                  PreSales Engineer
# 787683                               Senior Data Engineer
# 787684                              Senior Sales Engineer
# 787685                           IT Business Analyst Data
#
#                                   job_location                     job_via  \
# 0       Bari, Metropolitan City of Bari, Italy                via LinkedIn
# 1                        Vancouver, BC, Canada                via LinkedIn
# 2                                 New York, NY                via LinkedIn
# 3                                Hamtramck, MI                   via BeBee
# 4                                     Anywhere               via Jobgether
# ...                                        ...                         ...
# 787681                      Heidelberg, Jerman  melalui Top County Careers
# 787682                      Almaty, Kazakhstan               melalui Melga
# 787683                          Berlin, Jerman  melalui Top County Careers
# 787684                           Jenewa, Swiss       melalui BeBee Schweiz
# 787685                                  Jerman              melalui Indeed
#
#        job_schedule_type
# 0              Full-time
# 1              Full-time
# 2              Full-time
# 3              Full-time
# 4              Full-time
# ...                  ...
# 787681   Pekerjaan tetap
# 787682   Pekerjaan tetap
# 787683   Pekerjaan tetap
# 787684   Pekerjaan tetap
# 787685   Pekerjaan tetap
#
# [787686 rows x 5 columns]

# %% [markdown]
# ## loc
#
# ### Notes
#
# * `df.loc[]`: Select rows and columns by position or label.
# * Similar to `df.iloc[]` except we can use labels instead.
#
# ### Example
#
# Let's get the same columns we did before but with `loc` instead. Which uses column and row labels. These are:
#
# 1. Get the first row (index 0)
# 2. Get the first 10 rows of `job_skills` and `job_type_skills`.
# 3. Get the first 5 columns and rows 10-20.
# 4. Get the first 12 rows of the DataFrame.
# 5. Get the first five columns of the DataFrame and all of the rows.

# %% [markdown]
# 1. Get the first row. This remains the same because the row doesn't have a label.

# %%
df.loc[0]
# Out:
# job_title_short                                              Data Engineer
# job_title                    DevOps Engineer - Big Data/Advanced Analytics
# job_location                        Bari, Metropolitan City of Bari, Italy
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                      Italy
# job_posted_date                                        2023-10-24 18:16:15
# job_no_degree_mention                                                 True
# job_health_insurance                                                 False
# job_country                                                          Italy
# salary_rate                                                            NaN
# salary_year_avg                                                        NaN
# salary_hour_avg                                                        NaN
# company_name                                               NTT DATA Italia
# job_skills               ['shell', 'python', 'bash', 'mongodb', 'mongod...
# job_type_skills          {'cloud': ['gcp', 'aws', 'azure'], 'databases'...
# Name: 0, dtype: object

# %% [markdown]
# 2. Get the first 10 rows of `job_skills` and `job_type_skills`

# %%
df.loc[:9,['job_skills','job_type_skills']]
# Out:
#                                           job_skills  \
# 0  ['shell', 'python', 'bash', 'mongodb', 'mongod...
# 1  ['java', 'c#', 'mysql', 'oracle', 'docker', 'k...
# 2                                         ['python']
# 3  ['sql', 'r', 'scala', 'java', 'gcp', 'aws', 'h...
# 4  ['python', 'aws', 'tableau', 'looker', 'terraf...
# 5  ['python', 'nosql', 'sql', 'aws', 'redshift', ...
# 6  ['sql', 'python', 'java', 'scala', 'aws', 'spa...
# 7                  ['c', 'python', 'github', 'zoom']
# 8  ['sql', 'python', 'aws', 'databricks', 'spark'...
# 9                          ['sql', 'azure', 'spark']
#
#                                      job_type_skills
# 0  {'cloud': ['gcp', 'aws', 'azure'], 'databases'...
# 1  {'cloud': ['oracle'], 'databases': ['mysql'], ...
# 2                        {'programming': ['python']}
# 3  {'analyst_tools': ['tableau', 'sap', 'word'], ...
# 4  {'analyst_tools': ['tableau', 'looker'], 'asyn...
# 5  {'cloud': ['aws', 'redshift'], 'other': ['flow...
# 6  {'cloud': ['aws'], 'libraries': ['spark'], 'ot...
# 7  {'other': ['github'], 'programming': ['c', 'py...
# 8  {'cloud': ['aws', 'databricks'], 'libraries': ...
# 9  {'cloud': ['azure'], 'libraries': ['spark'], '...

# %%
df.loc[:9][['job_skills','job_type_skills']]
# Out:
#                                           job_skills  \
# 0  ['shell', 'python', 'bash', 'mongodb', 'mongod...
# 1  ['java', 'c#', 'mysql', 'oracle', 'docker', 'k...
# 2                                         ['python']
# 3  ['sql', 'r', 'scala', 'java', 'gcp', 'aws', 'h...
# 4  ['python', 'aws', 'tableau', 'looker', 'terraf...
# 5  ['python', 'nosql', 'sql', 'aws', 'redshift', ...
# 6  ['sql', 'python', 'java', 'scala', 'aws', 'spa...
# 7                  ['c', 'python', 'github', 'zoom']
# 8  ['sql', 'python', 'aws', 'databricks', 'spark'...
# 9                          ['sql', 'azure', 'spark']
#
#                                      job_type_skills
# 0  {'cloud': ['gcp', 'aws', 'azure'], 'databases'...
# 1  {'cloud': ['oracle'], 'databases': ['mysql'], ...
# 2                        {'programming': ['python']}
# 3  {'analyst_tools': ['tableau', 'sap', 'word'], ...
# 4  {'analyst_tools': ['tableau', 'looker'], 'asyn...
# 5  {'cloud': ['aws', 'redshift'], 'other': ['flow...
# 6  {'cloud': ['aws'], 'libraries': ['spark'], 'ot...
# 7  {'other': ['github'], 'programming': ['c', 'py...
# 8  {'cloud': ['aws', 'databricks'], 'libraries': ...
# 9  {'cloud': ['azure'], 'libraries': ['spark'], '...

# %% [markdown]
# 3. Get the first 5 columns and rows 10-20.

# %%
df.loc[10:20,'job_title_short':'job_work_from_home']
# Out:
#           job_title_short                                          job_title  \
# 10         Data Scientist           Data Scientist, Senior (Experimentation)
# 11           Data Analyst                                     Data Architect
# 12          Data Engineer  Informatiker als Data Engineer / Data Platform...
# 13         Data Scientist                  Gartner - Director - Data Science
# 14  Senior Data Scientist      Senior Data Scientist with Security Clearance
# 15  Senior Data Scientist            Senior Data Scientist Model Performance
# 16         Data Scientist                                     Data Scientist
# 17          Data Engineer                                  GCP Data Engineer
# 18   Senior Data Engineer            Senior Engineer, Data Insights (Remote)
# 19          Data Engineer                             Data Engineer- Sr Jobs
# 20          Data Engineer                                      Data Engineer
#
#                 job_location                job_via job_schedule_type  \
# 10                  Anywhere          via Jobgether         Full-time
# 11       Toronto, ON, Canada           via LinkedIn         Full-time
# 12           Munich, Germany  via My ArkLaMiss Jobs         Full-time
# 13  Gurugram, Haryana, India        via BeBee India         Full-time
# 14           Springfield, MO        via Trabajo.org         Full-time
# 15           Minneapolis, MN          via WJTV Jobs         Full-time
# 16                  Anywhere           via LinkedIn         Full-time
# 17                  Anywhere           via LinkedIn        Contractor
# 18                  Anywhere       via ZipRecruiter         Full-time
# 19            Washington, DC     via Clearance Jobs         Full-time
# 20            Des Moines, IA           via LinkedIn         Full-time
#
#     job_work_from_home
# 10                True
# 11               False
# 12               False
# 13               False
# 14               False
# 15               False
# 16                True
# 17                True
# 18                True
# 19               False
# 20               False
