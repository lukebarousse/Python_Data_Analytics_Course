# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/1_Basics/Extra/Pandas_Extract_from_Datetime.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Pandas Date and Time

# %% [markdown]
# Load data.

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# So far all we've learned when handling dates is to extract the date. But what if we wanted to extract other information? Like month or year?

# %% [markdown]
# ## Extract Month
#
# ### Notes
#
# * `dt.month`: extract the month from a datetime in a DataFrame.
# * `dt`: accessor that provides a way to access specialized methods and properties we use to work with datatime data within a pandas series.
# * `month`: extract the month component from the datetime object in the series.
# * Use together `dt.month` on our series.
#
# ### Example
#
# We are going to extract the month from the `job_posted_date` column.

# %%
df['job_posted_date'].dt.month
# Out:
# 0         10
# 1          5
# 2          7
# 3         11
# 4          8
#           ..
# 787681     3
# 787682     3
# 787683     3
# 787684     3
# 787685     3
# Name: job_posted_date, Length: 787686, dtype: int32

# %% [markdown]
# Now if we compare it with the `job_posted_date` column using `iloc[]` to get the first 10 rows and first 8 columns of our DataFrame we can see that it's correctly getting the month from the column.
#
# *Reminder*: `job_posted_date` is in this format: `YYYY-MM-DD HH:MM:SS`.

# %%
df.iloc[:10,:9]
# Out:
#         job_title_short                                          job_title  \
# 0         Data Engineer      DevOps Engineer - Big Data/Advanced Analytics
# 1         Data Engineer     Co-Op/Intern Software Engineer, Data Ingestion
# 2         Data Engineer                             Hybrid - Data Engineer
# 3        Data Scientist                                     Data Scientist
# 4         Data Engineer  Data Lead Engineer (with strong Python) - Remo...
# 5  Senior Data Engineer                               Senior Data Engineer
# 6         Data Engineer                                      Data Engineer
# 7          Data Analyst      Applied Mathematician, Scientist, or Engineer
# 8  Senior Data Engineer  Sr. Big Data Engineer with Data Bricks, Loc - ...
# 9         Data Engineer                                Azure Data Engineer
#
#                              job_location            job_via  \
# 0  Bari, Metropolitan City of Bari, Italy       via LinkedIn
# ...

# %% [markdown]
# ## Extract Year
#
# ### Notes
#
# * `dt.year`: extract the year from a datetime in a DataFrame.
# * `dt`: accessor that provides a way to access specialized methods and properties we use to work with datatime data within a pandas series.
# * `year`: extract the month component from the datetime object in the series.
# * Use together `dt.year` on our series.
#
# ### Example
#
# Now we are going to extract the year from the `job_posted_date` column.

# %%
df['job_posted_date'].dt.year
# Out:
# 0         2023
# 1         2023
# 2         2023
# 3         2023
# 4         2023
#           ...
# 787681    2023
# 787682    2023
# 787683    2023
# 787684    2023
# 787685    2023
# Name: job_posted_date, Length: 787686, dtype: int32

# %% [markdown]
# Again let's check our DataFrame.

# %%
df.iloc[:10,:9]
# Out:
#         job_title_short                                          job_title  \
# 0         Data Engineer      DevOps Engineer - Big Data/Advanced Analytics
# 1         Data Engineer     Co-Op/Intern Software Engineer, Data Ingestion
# 2         Data Engineer                             Hybrid - Data Engineer
# 3        Data Scientist                                     Data Scientist
# 4         Data Engineer  Data Lead Engineer (with strong Python) - Remo...
# 5  Senior Data Engineer                               Senior Data Engineer
# 6         Data Engineer                                      Data Engineer
# 7          Data Analyst      Applied Mathematician, Scientist, or Engineer
# 8  Senior Data Engineer  Sr. Big Data Engineer with Data Bricks, Loc - ...
# 9         Data Engineer                                Azure Data Engineer
#
#                              job_location            job_via  \
# 0  Bari, Metropolitan City of Bari, Italy       via LinkedIn
# ...
