# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/1_07_Conditional Statements.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## 🟩 Determine Python Experience (1.7.1)

# %%
# Code Needed
python_experience = 3
if python_experience < 2:
  print('Beginner level')
else:
  print('Intermediate')
# Out:
# Intermediate

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Determine Job Skill Level (1.7.2)

# %%
# Code Needed
tools_known = 3
if tools_known < 2:
  skill_level = 'Beginner'
elif tools_known < 5:
  skill_level = 'Intermediate'
else:
  skill_level = 'Advanced'
print(skill_level)
# Out:
# Intermediate

# %% [markdown]
# ---

# %% [markdown]
# ## 🟥 Determine Job Title (1.7.3)

# %%
# Code Needed
job_experience = 4
sql_experience = 2
if job_experience < 2:
  skill_level = 'Junior'
elif job_experience < 6 and sql_experience == 1:
  skill_level = 'Intermediate'
elif job_experience < 6 and sql_experience >= 2:
  skill_level = 'Senior'
elif job_experience > 5 and sql_experience >= 3:
  skill_level = 'Lead'
else:
  skill_level = 'Data'

title = skill_level + ' Analyst'
print(title)
# Out:
# Senior Analyst

# %% [markdown]
# ---
