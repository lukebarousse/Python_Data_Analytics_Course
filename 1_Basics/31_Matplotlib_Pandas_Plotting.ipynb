# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/1_Basics/31_Matplotlib_Pandas_Plotting.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Plotting Using Pandas

# %% [markdown]
# Load data.

# %%
# Install datasets Library (if not already installed)
# !pip install datasets

# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# ## Notes
#
# It is possible to plot things using Pandas. While it's more common to use a dedicated library like Matplotlib for graphing, you can use Pandas to create graphs. This is mostly used as a way to quickly create a graph for an analysis.
#
# We won't be focusing on it during this course but it's available if you want to.
#
# View more on that [here](https://pandas.pydata.org/docs/user_guide/visualization.html).
#
# ## Plotting Series
#
# Below is the data created in `29_Matplotlib_Plotting.ipynb`:

# %%
job_counts = df['job_title_short'].value_counts()

job_counts
# Out:
# job_title_short
# Data Analyst                 196593
# Data Engineer                186678
# Data Scientist               172727
# Business Analyst              49160
# Software Engineer             45019
# Senior Data Engineer          44692
# Senior Data Scientist         37076
# Senior Data Analyst           29289
# Machine Learning Engineer     14106
# Cloud Engineer                12346
# Name: count, dtype: int64

# %% [markdown]
# Plotting it with only Matplotlib:

# %%
plt.bar(job_counts.index, job_counts) 
plt.show()

# %% [markdown]
# Note: We'll fix formatting in a bit...
#
# Anyway, this is the same chart but using `Pandas` to plot it instead.

# %%
job_counts.plot(kind='bar')
plt.show()

# %% [markdown]
# We can even customize all the labels just like we did in Matplotlib.

# %%
job_counts.plot(kind='bar')
plt.xlabel('')
plt.ylabel('Count of Postings')
plt.title('Job Postings by Job Title')
plt.xticks(rotation=45, ha='right') 
plt.show()

# %% [markdown]
# ## Plotting Dataframes

# %%
df.plot(x='job_posted_date', y='salary_year_avg', kind='line')
# Out:
# <Axes: xlabel='job_posted_date'>

# %% [markdown]
# The problem with DataFrames (at least large ones) is the data still may need to be cleaned up.

# %%
# sort index by job posted date 
df = df.set_index('job_posted_date')
df.sort_index(inplace=True)
df.head()
# Out:
#                            job_title_short                    job_title  \
# job_posted_date
# 2022-12-31 06:01:15           Data Analyst  BA/Data Analyst with Oracle
# 2022-12-31 06:01:17           Data Analyst             Data Analyst III
# 2022-12-31 06:01:32    Senior Data Analyst          Senior Data Analyst
# 2022-12-31 06:02:02         Data Scientist               Data Scientist
# 2022-12-31 06:02:12  Senior Data Scientist        Senior Data Scientist
#
#                         job_location                job_via job_schedule_type  \
# job_posted_date
# 2022-12-31 06:01:15       Irving, TX   via Big Country Jobs         Full-time
# 2022-12-31 06:01:17  San Antonio, TX              via BeBee         Full-time
# 2022-12-31 06:01:32      Chicago, IL              via BeBee         Full-time
# 2022-12-31 06:02:02     New York, NY            via Monster         Full-time
# 2022-12-31 06:02:12   Marysville, OH  via My Stateline Jobs         Full-time
#
#                      job_work_from_home          search_location  \
# job_posted_date
# 2022-12-31 06:01:15               False     Texas, United States
# 2022-12-31 06:01:17               False     Texas, United States
# 2022-12-31 06:01:32               False  Illinois, United States
# 2022-12-31 06:02:02               False  New York, United States
# 2022-12-31 06:02:12               False  New York, United States
#
#                      job_no_degree_mention  job_health_insurance  \
# job_posted_date
# 2022-12-31 06:01:15                  False                 False
# 2022-12-31 06:01:17                  False                  True
# 2022-12-31 06:01:32                   True                 False
# 2022-12-31 06:02:02                  False                  True
# 2022-12-31 06:02:12                  False                 False
#
#                        job_country salary_rate  salary_year_avg  \
# job_posted_date
# 2022-12-31 06:01:15  United States        None              NaN
# 2022-12-31 06:01:17  United States        None              NaN
# 2022-12-31 06:01:32  United States        None              NaN
# 2022-12-31 06:02:02  United States        None              NaN
# 2022-12-31 06:02:12  United States        None              NaN
#
#                      salary_hour_avg                     company_name  \
# job_posted_date
# 2022-12-31 06:01:15              NaN   LTI - Larsen & Toubro Infotech
# 2022-12-31 06:01:17              NaN              Superior HealthPlan
# 2022-12-31 06:01:32              NaN  Quantum World Technologies Inc.
# 2022-12-31 06:02:02              NaN                       Afficiency
# 2022-12-31 06:02:12              NaN                            Rudis
#
#                                                             job_skills  \
# job_posted_date
# 2022-12-31 06:01:15                                   ['sql', 'excel']
# 2022-12-31 06:01:17                                   ['sql', 'excel']
# 2022-12-31 06:01:32  ['sql', 't-sql', 'mongo', 'python', 'java', 'o...
# 2022-12-31 06:02:02  ['sql', 'r', 'python', 'java', 'kotlin', 'matl...
# 2022-12-31 06:02:12                ['sql', 'r', 'tableau', 'power bi']
#
#                                                        job_type_skills
# job_posted_date
# 2022-12-31 06:01:15  {'analyst_tools': ['excel'], 'programming': ['...
# 2022-12-31 06:01:17  {'analyst_tools': ['excel'], 'programming': ['...
# 2022-12-31 06:01:32  {'analyst_tools': ['tableau', 'alteryx', 'ssis...
# 2022-12-31 06:02:02  {'analyst_tools': ['tableau'], 'libraries': ['...
# 2022-12-31 06:02:12  {'analyst_tools': ['tableau', 'power bi'], 'pr...

# %%
df.plot(y='salary_year_avg', kind='line')
# Out:
# <Axes: xlabel='job_posted_date'>
